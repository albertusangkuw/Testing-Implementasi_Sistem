# %%
def getFolder(mypath):
    from os import listdir
    return listdir(mypath)

# %%
def getMP3Folder(mypath):
    from os import listdir
    return [f for f in listdir(mypath) if f.endswith(".mp3")]

# %%
def getMetadata(mp3path):
    from tinytag import TinyTag
    tag = TinyTag.get(mp3path)
    payload = {}
    payload['artis'] = tag.artist
    payload['album'] = tag.album
    payload['title'] = tag.title
    payload['year'] = tag.year
    payload['genre'] = tag.genre
    payload['url'] = mp3path 
    return payload

# %%
path = "RepoSong"

# %%
artist = {}
artists = getFolder(path)
for x in artists :
    albums = getFolder(path + "/" + x)
    print(x + " : "  + str(len(albums)) + " album's")
    print(albums)
    detailAlbum = {}
    for y in albums :
        detailSongs = {}
        mp3files = getMP3Folder(path + "/" + x + "/" +  y)
        for z in mp3files :
            metadat = getMetadata(path + "/" + x + "/" +  y + "/" +  z)
            detailSongs[str(metadat['title'])] = metadat
        detailAlbum[str(y)] = detailSongs
    artist[str(x)] = detailAlbum
# Out:
# Avicii : 3 album's
# ['Stories', 'The Days _Nights', 'TIM']
# Justin Bieber : 1 album's
# ['Justice']
# Maroon 5 : 3 album's
# ['Overexposed', 'Red Pill Blues', 'The Best Songs']
# Martin Garrix : 2 album's
# ['Bylaw EP', 'Seven']
# Taylor Swift : 1 album's
# ['Lover']
# Twice : 3 album's
# ['&TWICE', 'FEEL SPECIAL', 'YES or YES']

# %%
from pprint import pprint
pprint(artist)
# Out:
# {'Avicii': {'Stories': {'Broken Arrows': {'album': 'Stories',
#                                           'artis': 'Avicii',
#                                           'genre': 'Electronic',
#                                           'title': 'Broken Arrows',
#                                           'url': 'RepoSong/Avicii/Stories/06. '
#                                                  'Broken Arrows.mp3',
#                                           'year': '2015'},
#                         "Can't Catch Me": {'album': 'Stories',
#                                            'artis': 'Avicii',
#                                            'genre': 'Electronic',
#                                            'title': "Can't Catch Me",
#                                            'url': 'RepoSong/Avicii/Stories/11. '
#                                                   "Can't Catch Me.mp3",
#                                            'year': '2015'},
#                         'City Lights': {'album': 'Stories',
#                                         'artis': 'Avicii',
#                                         'genre': 'Electronic',
#                                         'title': 'City Lights',
#                                         'url': 'RepoSong/Avicii/Stories/08. '
#                                                'City Lights.mp3',
#                                         'year': '2015'},
#                         'For A Better Day': {'album': 'Stories',
#                                              'artis': 'Avicii',
#                                              'genre': 'Electronic',
#                                              'title': 'For A Better Day',
#                                              'url': 'RepoSong/Avicii/Stories/05. '
#                                                     'For A Better Day.mp3',
#                                              'year': '2015'},
#                         'Gonna Love Ya': {'album': 'Stories',
#                                           'artis': 'Avicii',
#                                           'genre': 'Electronic',
#                                           'title': 'Gonna Love Ya',
#                                           'url': 'RepoSong/Avicii/Stories/14. '
#                                                  'Gonna Love Ya.mp3',
#                                           'year': '2015'},
#                         'Pure Grinding': {'album': 'Stories',
#                                           'artis': 'Avicii',
#                                           'genre': 'Electronic',
#                                           'title': 'Pure Grinding',
#                                           'url': 'RepoSong/Avicii/Stories/09. '
#                                                  'Pure Grinding.mp3',
#                                           'year': '2015'},
#                         'Somewhere In Stockholm': {'album': 'Stories',
#                                                    'artis': 'Avicii',
#                                                    'genre': 'Electronic',
#                                                    'title': 'Somewhere In '
#                                                             'Stockholm',
#                                                    'url': 'RepoSong/Avicii/Stories/12. '
#                                                           'Somewhere In '
#                                                           'Stockholm.mp3',
#                                                    'year': '2015'},
#                         'Sunset Jesus': {'album': 'Stories',
#                                          'artis': 'Avicii',
#                                          'genre': 'Electronic',
#                                          'title': 'Sunset Jesus',
#                                          'url': 'RepoSong/Avicii/Stories/10. '
#                                                 'Sunset Jesus.mp3',
#                                          'year': '2015'},
#                         'Talk To Myself': {'album': 'Stories',
#                                            'artis': 'Avicii',
#                                            'genre': 'Electronic',
#                                            'title': 'Talk To Myself',
#                                            'url': 'RepoSong/Avicii/Stories/02. '
#                                                   'Talk To Myself.mp3',
#                                            'year': '2015'},
#                         'Ten More Days': {'album': 'Stories',
#                                           'artis': 'Avicii',
#                                           'genre': 'Electronic',
#                                           'title': 'Ten More Days',
#                                           'url': 'RepoSong/Avicii/Stories/04. '
#                                                  'Ten More Days.mp3',
#                                           'year': '2015'},
#                         'The Days': {'album': 'Stories',
#                                      'artis': 'Avicii',
#                                      'genre': 'Electronic',
#                                      'title': 'The Days',
#                                      'url': 'RepoSong/Avicii/Stories/15. The '
#                                             'Days.mp3',
#                                      'year': '2015'},
#                         'The Nights': {'album': 'Stories',
#                                        'artis': 'Avicii',
#                                        'genre': 'Electronic',
#                                        'title': 'The Nights',
#                                        'url': 'RepoSong/Avicii/Stories/16. The '
#                                               'Nights.mp3',
#                                        'year': '2015'},
#                         'Touch Me': {'album': 'Stories',
#                                      'artis': 'Avicii',
#                                      'genre': 'Electronic',
#                                      'title': 'Touch Me',
#                                      'url': 'RepoSong/Avicii/Stories/03. Touch '
#                                             'Me.mp3',
#                                      'year': '2015'},
#                         'Trouble': {'album': 'Stories',
#                                     'artis': 'Avicii',
#                                     'genre': 'Electronic',
#                                     'title': 'Trouble',
#                                     'url': 'RepoSong/Avicii/Stories/13. '
#                                            'Trouble.mp3',
#                                     'year': '2015'},
#                         'True Believer': {'album': 'Stories',
#                                           'artis': 'Avicii',
#                                           'genre': 'Electronic',
#                                           'title': 'True Believer',
#                                           'url': 'RepoSong/Avicii/Stories/07. '
#                                                  'True Believer.mp3',
#                                           'year': '2015'},
#                         'Waiting For Love': {'album': 'Stories',
#                                              'artis': 'Avicii',
#                                              'genre': 'Electronic',
#                                              'title': 'Waiting For Love',
#                                              'url': 'RepoSong/Avicii/Stories/01. '
#                                                     'Waiting For Love.mp3',
#                                              'year': '2015'}},
#             'TIM': {"Ain't A Thing (feat. Bonn)": {'album': 'TIM',
#                                                    'artis': 'Avicii',
#                                                    'genre': 'Dance',
#                                                    'title': "Ain't A Thing "
#                                                             '(feat. Bonn)',
#                                                    'url': 'RepoSong/Avicii/TIM/06 '
#                                                           "Ain't A Thing "
#                                                           '(feat. Bonn).mp3',
#                                                    'year': '2019'},
#                     'Bad Reputation (feat. Joe Janiak)': {'album': 'TIM',
#                                                           'artis': 'Avicii',
#                                                           'genre': 'Dance',
#                                                           'title': 'Bad '
#                                                                    'Reputation '
#                                                                    '(feat. Joe '
#                                                                    'Janiak)',
#                                                           'url': 'RepoSong/Avicii/TIM/05 '
#                                                                  'Bad '
#                                                                  'Reputation '
#                                                                  '(feat. Joe '
#                                                                  'Janiak).mp3',
#                                                           'year': '2019'},
#                     'Excuse Me Mr Sir (feat. Vargas & Lagola)': {'album': 'TIM',
#                                                                  'artis': 'Avicii',
#                                                                  'genre': 'Dance',
#                                                                  'title': 'Excuse '
#                                                                           'Me '
#                                                                           'Mr '
#                                                                           'Sir '
#                                                                           '(feat. '
#                                                                           'Vargas '
#                                                                           '& '
#                                                                           'Lagola)',
#                                                                  'url': 'RepoSong/Avicii/TIM/09 '
#                                                                         'Excuse '
#                                                                         'Me Mr '
#                                                                         'Sir '
#                                                                         '(feat. '
#                                                                         'Vargas '
#                                                                         '&.mp3',
#                                                                  'year': '2019'},
#                     'Fades Away (feat. Noonie Bao)': {'album': 'TIM',
#                                                       'artis': 'Avicii',
#                                                       'genre': 'Dance',
#                                                       'title': 'Fades Away '
#                                                                '(feat. Noonie '
#                                                                'Bao)',
#                                                       'url': 'RepoSong/Avicii/TIM/12 '
#                                                              'Fades Away '
#                                                              '(feat. Noonie '
#                                                              'Bao).mp3',
#                                                       'year': '2019'},
#                     'Freak (feat. Bonn)': {'album': 'TIM',
#                                            'artis': 'Avicii',
#                                            'genre': 'Dance',
#                                            'title': 'Freak (feat. Bonn)',
#                                            'url': 'RepoSong/Avicii/TIM/08 '
#                                                   'Freak (feat. Bonn).mp3',
#                                            'year': '2019'},
#                     'Heart Upon My Sleeve': {'album': 'TIM',
#                                              'artis': 'Avicii & Imagine '
#                                                       'Dragons',
#                                              'genre': 'Dance',
#                                              'title': 'Heart Upon My Sleeve',
#                                              'url': 'RepoSong/Avicii/TIM/10 '
#                                                     'Heart Upon My Sleeve.mp3',
#                                              'year': '2019'},
#                     'Heaven': {'album': 'TIM',
#                                'artis': 'Avicii',
#                                'genre': 'Dance',
#                                'title': 'Heaven',
#                                'url': 'RepoSong/Avicii/TIM/02 Heaven.mp3',
#                                'year': '2019'},
#                     'Hold The Line (feat. A R I Z O N A)': {'album': 'TIM',
#                                                             'artis': 'Avicii',
#                                                             'genre': 'Dance',
#                                                             'title': 'Hold The '
#                                                                      'Line '
#                                                                      '(feat. A '
#                                                                      'R I Z O '
#                                                                      'N A)',
#                                                             'url': 'RepoSong/Avicii/TIM/07 '
#                                                                    'Hold The '
#                                                                    'Line '
#                                                                    '(feat. A R '
#                                                                    'I Z O '
#                                                                    'N.mp3',
#                                                             'year': '2019'},
#                     'Never Leave Me (feat. Joe Janiak)': {'album': 'TIM',
#                                                           'artis': 'Avicii',
#                                                           'genre': 'Dance',
#                                                           'title': 'Never '
#                                                                    'Leave Me '
#                                                                    '(feat. Joe '
#                                                                    'Janiak)',
#                                                           'url': 'RepoSong/Avicii/TIM/11 '
#                                                                  'Never Leave '
#                                                                  'Me (feat. '
#                                                                  'Joe '
#                                                                  'Janiak).mp3',
#                                                           'year': '2019'},
#                     'Peace Of Mind (feat. Vargas & Lagola)': {'album': 'TIM',
#                                                               'artis': 'Avicii',
#                                                               'genre': 'Dance',
#                                                               'title': 'Peace '
#                                                                        'Of '
#                                                                        'Mind '
#                                                                        '(feat. '
#                                                                        'Vargas '
#                                                                        '& '
#                                                                        'Lagola)',
#                                                               'url': 'RepoSong/Avicii/TIM/01 '
#                                                                      'Peace Of '
#                                                                      'Mind '
#                                                                      '(feat. '
#                                                                      'Vargas & '
#                                                                      'Lag.mp3',
#                                                               'year': '2019'},
#                     'SOS (feat. Aloe Blacc)': {'album': 'TIM',
#                                                'artis': 'Avicii',
#                                                'genre': 'Dance',
#                                                'title': 'SOS (feat. Aloe '
#                                                         'Blacc)',
#                                                'url': 'RepoSong/Avicii/TIM/03 '
#                                                       'SOS (feat. Aloe '
#                                                       'Blacc).mp3',
#                                                'year': '2019'},
#                     'Tough Love (feat. Agnes & Vargas & Lagola)': {'album': 'TIM',
#                                                                    'artis': 'Avicii',
#                                                                    'genre': 'Dance',
#                                                                    'title': 'Tough '
#                                                                             'Love '
#                                                                             '(feat. '
#                                                                             'Agnes '
#                                                                             '& '
#                                                                             'Vargas '
#                                                                             '& '
#                                                                             'Lagola)',
#                                                                    'url': 'RepoSong/Avicii/TIM/04 '
#                                                                           'Tough '
#                                                                           'Love '
#                                                                           '(feat. '
#                                                                           'Agnes '
#                                                                           '& '
#                                                                           'Vargas.mp3',
#                                                                    'year': '2019'}},
#             'The Days _Nights': {'The Days': {'album': 'The Days / Nights (EP)',
#                                               'artis': 'Avicii',
#                                               'genre': 'Dance',
#                                               'title': 'The Days',
#                                               'url': 'RepoSong/Avicii/The Days '
#                                                      '_Nights/01 The Days.mp3',
#                                               'year': '2014-01-01T08:00:00Z'},
#                                  'The Days (Henrik B Remix)': {'album': 'The '
#                                                                         'Days '
#                                                                         '/ '
#                                                                         'Nights '
#                                                                         '(EP)',
#                                                                'artis': 'Avicii',
#                                                                'genre': 'Dance',
#                                                                'title': 'The '
#                                                                         'Days '
#                                                                         '(Henrik '
#                                                                         'B '
#                                                                         'Remix)',
#                                                                'url': 'RepoSong/Avicii/The '
#                                                                       'Days '
#                                                                       '_Nights/03 '
#                                                                       'The '
#                                                                       'Days '
#                                                                       '(Henrik '
#                                                                       'B '
#                                                                       'Remix).mp3',
#                                                                'year': '2014-01-01T08:00:00Z'},
#                                  'The Nights': {'album': 'The Days / Nights '
#                                                          '(EP)',
#                                                 'artis': 'Avicii',
#                                                 'genre': 'Dance',
#                                                 'title': 'The Nights',
#                                                 'url': 'RepoSong/Avicii/The '
#                                                        'Days _Nights/02 The '
#                                                        'Nights.mp3',
#                                                 'year': '2014-01-01T08:00:00Z'},
#                                  'The Nights (Felix Jaehn Remix)': {'album': 'The '
#                                                                              'Days '
#                                                                              '/ '
#                                                                              'Nights '
#                                                                              '(EP)',
#                                                                     'artis': 'Avicii',
#                                                                     'genre': 'Dance',
#                                                                     'title': 'The '
#                                                                              'Nights '
#                                                                              '(Felix '
#                                                                              'Jaehn '
#                                                                              'Remix)',
#                                                                     'url': 'RepoSong/Avicii/The '
#                                                                            'Days '
#                                                                            '_Nights/04 '
#                                                                            'The '
#                                                                            'Nights '
#                                                                            '(Felix '
#                                                                            'Jaehn '
#                                                                            'Remix).mp3',
#                                                                     'year': '2014-01-01T08:00:00Z'}}},
#  'Justin Bieber': {'Justice': {'2 Much': {'album': 'Justice',
#                                           'artis': 'Justin Bieber',
#                                           'genre': 'Pop',
#                                           'title': '2 Much',
#                                           'url': 'RepoSong/Justin '
#                                                  'Bieber/Justice/01. 2 '
#                                                  'Much.mp3',
#                                           'year': '2021'},
#                                'Anyone': {'album': 'Justice',
#                                           'artis': 'Justin Bieber',
#                                           'genre': 'Pop',
#                                           'title': 'Anyone',
#                                           'url': 'RepoSong/Justin '
#                                                  'Bieber/Justice/15. '
#                                                  'Anyone.mp3',
#                                           'year': '2021'},
#                                'As I Am': {'album': 'Justice',
#                                            'artis': 'Justin Bieber, Khalid',
#                                            'genre': 'Pop',
#                                            'title': 'As I Am',
#                                            'url': 'RepoSong/Justin '
#                                                   'Bieber/Justice/03. As I '
#                                                   'Am.mp3',
#                                            'year': '2021'},
#                                'Deserve You': {'album': 'Justice',
#                                                'artis': 'Justin Bieber',
#                                                'genre': 'Pop',
#                                                'title': 'Deserve You',
#                                                'url': 'RepoSong/Justin '
#                                                       'Bieber/Justice/02. '
#                                                       'Deserve You.mp3',
#                                                'year': '2021'},
#                                'Die For You': {'album': 'Justice',
#                                                'artis': 'Justin Bieber, '
#                                                         'Dominic Fike',
#                                                'genre': 'Pop',
#                                                'title': 'Die For You',
#                                                'url': 'RepoSong/Justin '
#                                                       'Bieber/Justice/08. Die '
#                                                       'For You.mp3',
#                                                'year': '2021'},
#                                'Ghost': {'album': 'Justice',
#                                          'artis': 'Justin Bieber',
#                                          'genre': 'Pop',
#                                          'title': 'Ghost',
#                                          'url': 'RepoSong/Justin '
#                                                 'Bieber/Justice/11. Ghost.mp3',
#                                          'year': '2021'},
#                                'Hold On': {'album': 'Justice',
#                                            'artis': 'Justin Bieber',
#                                            'genre': 'Pop',
#                                            'title': 'Hold On',
#                                            'url': 'RepoSong/Justin '
#                                                   'Bieber/Justice/09. Hold '
#                                                   'On.mp3',
#                                            'year': '2021'},
#                                'Holy': {'album': 'Justice',
#                                         'artis': 'Justin Bieber, Chance the '
#                                                  'Rapper',
#                                         'genre': 'Pop',
#                                         'title': 'Holy',
#                                         'url': 'RepoSong/Justin '
#                                                'Bieber/Justice/05. Holy.mp3',
#                                         'year': '2021'},
#                                'Lonely': {'album': 'Justice',
#                                           'artis': 'Justin Bieber, Benny '
#                                                    'Blanco',
#                                           'genre': 'Pop',
#                                           'title': 'Lonely',
#                                           'url': 'RepoSong/Justin '
#                                                  'Bieber/Justice/16. '
#                                                  'Lonely.mp3',
#                                           'year': '2021'},
#                                'Love You Different': {'album': 'Justice',
#                                                       'artis': 'Justin Bieber, '
#                                                                'Beam',
#                                                       'genre': 'Pop',
#                                                       'title': 'Love You '
#                                                                'Different',
#                                                       'url': 'RepoSong/Justin '
#                                                              'Bieber/Justice/13. '
#                                                              'Love You '
#                                                              'Different.mp3',
#                                                       'year': '2021'},
#                                'Loved By You': {'album': 'Justice',
#                                                 'artis': 'Justin Bieber, Burna '
#                                                          'Boy',
#                                                 'genre': 'Pop',
#                                                 'title': 'Loved By You',
#                                                 'url': 'RepoSong/Justin '
#                                                        'Bieber/Justice/14. '
#                                                        'Loved By You.mp3',
#                                                 'year': '2021'},
#                                'MLK Interlude': {'album': 'Justice',
#                                                  'artis': 'Justin Bieber',
#                                                  'genre': 'Pop',
#                                                  'title': 'MLK Interlude',
#                                                  'url': 'RepoSong/Justin '
#                                                         'Bieber/Justice/07. '
#                                                         'MLK Interlude.mp3',
#                                                  'year': '2021'},
#                                'Off My Face': {'album': 'Justice',
#                                                'artis': 'Justin Bieber',
#                                                'genre': 'Pop',
#                                                'title': 'Off My Face',
#                                                'url': 'RepoSong/Justin '
#                                                       'Bieber/Justice/04. Off '
#                                                       'My Face.mp3',
#                                                'year': '2021'},
#                                'Peaches': {'album': 'Justice',
#                                            'artis': 'Justin Bieber, Daniel '
#                                                     'Caesar, Giveon',
#                                            'genre': 'Pop',
#                                            'title': 'Peaches',
#                                            'url': 'RepoSong/Justin '
#                                                   'Bieber/Justice/12. '
#                                                   'Peaches.mp3',
#                                            'year': '2021'},
#                                'Somebody': {'album': 'Justice',
#                                             'artis': 'Justin Bieber',
#                                             'genre': 'Pop',
#                                             'title': 'Somebody',
#                                             'url': 'RepoSong/Justin '
#                                                    'Bieber/Justice/10. '
#                                                    'Somebody.mp3',
#                                             'year': '2021'},
#                                'Unstable': {'album': 'Justice',
#                                             'artis': 'Justin Bieber, The Kid '
#                                                      'Laroi',
#                                             'genre': 'Pop',
#                                             'title': 'Unstable',
#                                             'url': 'RepoSong/Justin '
#                                                    'Bieber/Justice/06. '
#                                                    'Unstable.mp3',
#                                             'year': '2021'}}},
#  'Maroon 5': {'Overexposed': {'Beautiful Goodbye': {'album': 'Overexposed '
#                                                              '(Deluxe Version)',
#                                                     'artis': 'Maroon 5',
#                                                     'genre': 'Pop',
#                                                     'title': 'Beautiful '
#                                                              'Goodbye',
#                                                     'url': 'RepoSong/Maroon '
#                                                            '5/Overexposed/12 '
#                                                            'Beautiful '
#                                                            'Goodbye.mp3',
#                                                     'year': '2012-06-20T07:00:00Z'},
#                               'Daylight': {'album': 'Overexposed (Deluxe '
#                                                     'Version)',
#                                            'artis': 'Maroon 5',
#                                            'genre': 'Pop',
#                                            'title': 'Daylight',
#                                            'url': 'RepoSong/Maroon '
#                                                   '5/Overexposed/03 '
#                                                   'Daylight.mp3',
#                                            'year': '2012-06-20T07:00:00Z'},
#                               "Doin' Dirt": {'album': 'Overexposed (Deluxe '
#                                                       'Version)',
#                                              'artis': 'Maroon 5',
#                                              'genre': 'Pop',
#                                              'title': "Doin' Dirt",
#                                              'url': 'RepoSong/Maroon '
#                                                     "5/Overexposed/11 Doin' "
#                                                     'Dirt.mp3',
#                                              'year': '2012-06-20T07:00:00Z'},
#                               'Fortune Teller': {'album': 'Overexposed (Deluxe '
#                                                           'Version)',
#                                                  'artis': 'Maroon 5',
#                                                  'genre': 'Pop',
#                                                  'title': 'Fortune Teller',
#                                                  'url': 'RepoSong/Maroon '
#                                                         '5/Overexposed/08 '
#                                                         'Fortune Teller.mp3',
#                                                  'year': '2012-06-20T07:00:00Z'},
#                               'Kiss': {'album': 'Overexposed (Deluxe Version)',
#                                        'artis': 'Maroon 5',
#                                        'genre': 'Pop',
#                                        'title': 'Kiss',
#                                        'url': 'RepoSong/Maroon '
#                                               '5/Overexposed/15 Kiss.mp3',
#                                        'year': '2012-06-20T07:00:00Z'},
#                               'Ladykiller': {'album': 'Overexposed (Deluxe '
#                                                       'Version)',
#                                              'artis': 'Maroon 5',
#                                              'genre': 'Pop',
#                                              'title': 'Ladykiller',
#                                              'url': 'RepoSong/Maroon '
#                                                     '5/Overexposed/07 '
#                                                     'Ladykiller.mp3',
#                                              'year': '2012-06-20T07:00:00Z'},
#                               'Love Somebody': {'album': 'Overexposed (Deluxe '
#                                                          'Version)',
#                                                 'artis': 'Maroon 5',
#                                                 'genre': 'Pop',
#                                                 'title': 'Love Somebody',
#                                                 'url': 'RepoSong/Maroon '
#                                                        '5/Overexposed/06 Love '
#                                                        'Somebody.mp3',
#                                                 'year': '2012-06-20T07:00:00Z'},
#                               'Lucky Strike': {'album': 'Overexposed (Deluxe '
#                                                         'Version)',
#                                                'artis': 'Maroon 5',
#                                                'genre': 'Pop',
#                                                'title': 'Lucky Strike',
#                                                'url': 'RepoSong/Maroon '
#                                                       '5/Overexposed/04 Lucky '
#                                                       'Strike.mp3',
#                                                'year': '2012-06-20T07:00:00Z'},
#                               'Moves Like Jagger (feat. Christina Aguilera) [Studio Recording from The Voice Performance]': {'album': 'Overexposed '
#                                                                                                                                       '(Deluxe '
#                                                                                                                                       'Version)',
#                                                                                                                              'artis': 'Maroon '
#                                                                                                                                       '5',
#                                                                                                                              'genre': 'Pop',
#                                                                                                                              'title': 'Moves '
#                                                                                                                                       'Like '
#                                                                                                                                       'Jagger '
#                                                                                                                                       '(feat. '
#                                                                                                                                       'Christina '
#                                                                                                                                       'Aguilera) '
#                                                                                                                                       '[Studio '
#                                                                                                                                       'Recording '
#                                                                                                                                       'from '
#                                                                                                                                       'The '
#                                                                                                                                       'Voice '
#                                                                                                                                       'Performance]',
#                                                                                                                              'url': 'RepoSong/Maroon '
#                                                                                                                                     '5/Overexposed/16 '
#                                                                                                                                     'Moves '
#                                                                                                                                     'Like '
#                                                                                                                                     'Jagger '
#                                                                                                                                     '(feat. '
#                                                                                                                                     'Christin.mp3',
#                                                                                                                              'year': '2012-06-20T07:00:00Z'},
#                               'One More Night': {'album': 'Overexposed (Deluxe '
#                                                           'Version)',
#                                                  'artis': 'Maroon 5',
#                                                  'genre': 'Pop',
#                                                  'title': 'One More Night',
#                                                  'url': 'RepoSong/Maroon '
#                                                         '5/Overexposed/01 One '
#                                                         'More Night.mp3',
#                                                  'year': '2012-06-20T07:00:00Z'},
#                               'One More Night (Sticky K Remix)': {'album': 'Overexposed '
#                                                                            '(Deluxe '
#                                                                            'Version)',
#                                                                   'artis': 'Maroon '
#                                                                            '5',
#                                                                   'genre': 'Pop',
#                                                                   'title': 'One '
#                                                                            'More '
#                                                                            'Night '
#                                                                            '(Sticky '
#                                                                            'K '
#                                                                            'Remix)',
#                                                                   'url': 'RepoSong/Maroon '
#                                                                          '5/Overexposed/17 '
#                                                                          'One '
#                                                                          'More '
#                                                                          'Night '
#                                                                          '(Sticky '
#                                                                          'K '
#                                                                          'Remix).mp3',
#                                                                   'year': '2012-06-20T07:00:00Z'},
#                               'Payphone (feat. Wiz Khalifa)': {'album': 'Overexposed '
#                                                                         '(Deluxe '
#                                                                         'Version)',
#                                                                'artis': 'Maroon '
#                                                                         '5',
#                                                                'genre': 'Pop',
#                                                                'title': 'Payphone '
#                                                                         '(feat. '
#                                                                         'Wiz '
#                                                                         'Khalifa)',
#                                                                'url': 'RepoSong/Maroon '
#                                                                       '5/Overexposed/02 '
#                                                                       'Payphone '
#                                                                       '(feat. '
#                                                                       'Wiz '
#                                                                       'Khalifa).mp3',
#                                                                'year': '2012-06-20T07:00:00Z'},
#                               'Payphone (feat. Wiz Khalifa) [Cutmore Remix]': {'album': 'Overexposed '
#                                                                                         '(Deluxe '
#                                                                                         'Version)',
#                                                                                'artis': 'Maroon '
#                                                                                         '5',
#                                                                                'genre': 'Pop',
#                                                                                'title': 'Payphone '
#                                                                                         '(feat. '
#                                                                                         'Wiz '
#                                                                                         'Khalifa) '
#                                                                                         '[Cutmore '
#                                                                                         'Remix]',
#                                                                                'url': 'RepoSong/Maroon '
#                                                                                       '5/Overexposed/18 '
#                                                                                       'Payphone '
#                                                                                       '(feat. '
#                                                                                       'Wiz '
#                                                                                       'Khalifa) '
#                                                                                       '[Cut.mp3',
#                                                                                'year': '2012-06-20T07:00:00Z'},
#                               'Payphone (feat. Wiz Khalifa) [Sound of Arrows Remix]': {'album': 'Overexposed '
#                                                                                                 '(Deluxe '
#                                                                                                 'Version)',
#                                                                                        'artis': 'Maroon '
#                                                                                                 '5',
# ...
#                                                                               'Heartbreak '
#                                                                               'P.mp3',
#                                                                        'year': '2019'},
#                             'Paper Rings': {'album': 'Lover',
#                                             'artis': 'Taylor Swift',
#                                             'genre': 'Pop',
#                                             'title': 'Paper Rings',
#                                             'url': 'RepoSong/Taylor '
#                                                    'Swift/Lover/08 Paper '
#                                                    'Rings.mp3',
#                                             'year': '2019'},
#                             "Soon You'll Get Better (feat. Dixie Chicks)": {'album': 'Lover',
#                                                                             'artis': 'Taylor '
#                                                                                      'Swift',
#                                                                             'genre': 'Pop',
#                                                                             'title': 'Soon '
#                                                                                      "You'll "
#                                                                                      'Get '
#                                                                                      'Better '
#                                                                                      '(feat. '
#                                                                                      'Dixie '
#                                                                                      'Chicks)',
#                                                                             'url': 'RepoSong/Taylor '
#                                                                                    'Swift/Lover/12 '
#                                                                                    'Soon '
#                                                                                    "You'll "
#                                                                                    'Get '
#                                                                                    'Better '
#                                                                                    '(feat. '
#                                                                                    'Dix.mp3',
#                                                                             'year': '2019'},
#                             'The Archer': {'album': 'Lover',
#                                            'artis': 'Taylor Swift',
#                                            'genre': 'Pop',
#                                            'title': 'The Archer',
#                                            'url': 'RepoSong/Taylor '
#                                                   'Swift/Lover/05 The '
#                                                   'Archer.mp3',
#                                            'year': '2019'},
#                             'The Man': {'album': 'Lover',
#                                         'artis': 'Taylor Swift',
#                                         'genre': 'Pop',
#                                         'title': 'The Man',
#                                         'url': 'RepoSong/Taylor Swift/Lover/04 '
#                                                'The Man.mp3',
#                                         'year': '2019'},
#                             'You Need To Calm Down': {'album': 'Lover',
#                                                       'artis': 'Taylor Swift',
#                                                       'genre': 'Pop',
#                                                       'title': 'You Need To '
#                                                                'Calm Down',
#                                                       'url': 'RepoSong/Taylor '
#                                                              'Swift/Lover/14 '
#                                                              'You Need To Calm '
#                                                              'Down.mp3',
#                                                       'year': '2019'}}},
#  'Twice': {'&TWICE': {'Be OK': {'album': '&TWICE',
#                                 'artis': 'Twice',
#                                 'genre': 'K-Pop',
#                                 'title': 'Be OK',
#                                 'url': 'RepoSong/Twice/&TWICE/07 Be OK.mp3',
#                                 'year': '2019'},
#                       'Breakthrough': {'album': '&TWICE',
#                                        'artis': 'Twice',
#                                        'genre': 'K-Pop',
#                                        'title': 'Breakthrough',
#                                        'url': 'RepoSong/Twice/&TWICE/03 '
#                                               'Breakthrough.mp3',
#                                        'year': '2019'},
#                       'Changing!': {'album': '&TWICE',
#                                     'artis': 'Twice',
#                                     'genre': 'K-Pop',
#                                     'title': 'Changing!',
#                                     'url': 'RepoSong/Twice/&TWICE/04 '
#                                            'Changing!.mp3',
#                                     'year': '2019'},
#                       'Fake & True': {'album': '&TWICE',
#                                       'artis': 'Twice',
#                                       'genre': 'K-Pop',
#                                       'title': 'Fake & True',
#                                       'url': 'RepoSong/Twice/&TWICE/01 Fake & '
#                                              'True.mp3',
#                                       'year': '2019'},
#                       'HAPPY HAPPY': {'album': '&TWICE',
#                                       'artis': 'Twice',
#                                       'genre': 'K-Pop',
#                                       'title': 'HAPPY HAPPY',
#                                       'url': 'RepoSong/Twice/&TWICE/05 HAPPY '
#                                              'HAPPY.mp3',
#                                       'year': '2019'},
#                       "How u doin'": {'album': '&TWICE',
#                                       'artis': 'Twice',
#                                       'genre': 'K-Pop',
#                                       'title': "How u doin'",
#                                       'url': 'RepoSong/Twice/&TWICE/09 How u '
#                                              "doin'.mp3",
#                                       'year': '2019'},
#                       'POLISH': {'album': '&TWICE',
#                                  'artis': 'Twice',
#                                  'genre': 'K-Pop',
#                                  'title': 'POLISH',
#                                  'url': 'RepoSong/Twice/&TWICE/08 POLISH.mp3',
#                                  'year': '2019'},
#                       'Stronger': {'album': '&TWICE',
#                                    'artis': 'Twice',
#                                    'genre': 'K-Pop',
#                                    'title': 'Stronger',
#                                    'url': 'RepoSong/Twice/&TWICE/02 '
#                                           'Stronger.mp3',
#                                    'year': '2019'},
#                       'The Reason Why': {'album': '&TWICE',
#                                          'artis': 'Twice',
#                                          'genre': 'K-Pop',
#                                          'title': 'The Reason Why',
#                                          'url': 'RepoSong/Twice/&TWICE/10 The '
#                                                 'Reason Why.mp3',
#                                          'year': '2019'},
#                       'What You Waiting For': {'album': '&TWICE',
#                                                'artis': 'Twice',
#                                                'genre': 'K-Pop',
#                                                'title': 'What You Waiting For',
#                                                'url': 'RepoSong/Twice/&TWICE/06 '
#                                                       'What You Waiting '
#                                                       'For.mp3',
#                                                'year': '2019'}},
#            'FEEL SPECIAL': {'21:29': {'album': 'Feel Special',
#                                       'artis': 'TWICE (트와이스)',
#                                       'genre': 'Ballad',
#                                       'title': '21:29',
#                                       'url': 'RepoSong/Twice/FEEL SPECIAL/06. '
#                                              '21_29.mp3',
#                                       'year': ''},
#                             'BREAKTHROUGH (Korean Ver.)': {'album': 'Feel '
#                                                                     'Special',
#                                                            'artis': 'TWICE '
#                                                                     '(트와이스)',
#                                                            'genre': 'Dance',
#                                                            'title': 'BREAKTHROUGH '
#                                                                     '(Korean '
#                                                                     'Ver.)',
#                                                            'url': 'RepoSong/Twice/FEEL '
#                                                                   'SPECIAL/07. '
#                                                                   'BREAKTHROUGH '
#                                                                   '(Korean '
#                                                                   'Ver.).mp3',
#                                                            'year': ''},
#                             'Feel Special': {'album': 'Feel Special',
#                                              'artis': 'TWICE (트와이스)',
#                                              'genre': 'Dance',
#                                              'title': 'Feel Special',
#                                              'url': 'RepoSong/Twice/FEEL '
#                                                     'SPECIAL/01. Feel '
#                                                     'Special.mp3',
#                                              'year': ''},
#                             'GET LOUD': {'album': 'Feel Special',
#                                          'artis': 'TWICE (트와이스)',
#                                          'genre': 'Dance',
#                                          'title': 'GET LOUD',
#                                          'url': 'RepoSong/Twice/FEEL '
#                                                 'SPECIAL/03. GET LOUD.mp3',
#                                          'year': ''},
#                             'LOVE FOOLISH': {'album': 'Feel Special',
#                                              'artis': 'TWICE (트와이스)',
#                                              'genre': 'Electronica',
#                                              'title': 'LOVE FOOLISH',
#                                              'url': 'RepoSong/Twice/FEEL '
#                                                     'SPECIAL/05. LOVE '
#                                                     'FOOLISH.mp3',
#                                              'year': ''},
#                             'RAINBOW': {'album': 'Feel Special',
#                                         'artis': 'TWICE (트와이스)',
#                                         'genre': 'Dance',
#                                         'title': 'RAINBOW',
#                                         'url': 'RepoSong/Twice/FEEL '
#                                                'SPECIAL/02. RAINBOW.mp3',
#                                         'year': ''},
#                             'TRICK IT': {'album': 'Feel Special',
#                                          'artis': 'TWICE (트와이스)',
#                                          'genre': 'Dance',
#                                          'title': 'TRICK IT',
#                                          'url': 'RepoSong/Twice/FEEL '
#                                                 'SPECIAL/04. TRICK IT.mp3',
#                                          'year': ''}},
#            'YES or YES': {'AFTER MOON': {'album': 'YES or YES',
#                                          'artis': 'TWICE (트와이스)',
#                                          'genre': 'Ballad',
#                                          'title': 'AFTER MOON',
#                                          'url': 'RepoSong/Twice/YES or YES/06. '
#                                                 'AFTER MOON.mp3',
#                                          'year': '20181105'},
#                           'BDZ (Korean Ver.)': {'album': 'YES or YES',
#                                                 'artis': 'TWICE (트와이스)',
#                                                 'genre': 'Dance',
#                                                 'title': 'BDZ (Korean Ver.)',
#                                                 'url': 'RepoSong/Twice/YES or '
#                                                        'YES/07. BDZ (Korean '
#                                                        'Ver.).mp3',
#                                                 'year': '20181105'},
#                           'LALALA': {'album': 'YES or YES',
#                                      'artis': 'TWICE (트와이스)',
#                                      'genre': 'Dance',
#                                      'title': 'LALALA',
#                                      'url': 'RepoSong/Twice/YES or YES/03. '
#                                             'LALALA.mp3',
#                                      'year': '20181105'},
#                           'SAY YOU LOVE ME': {'album': 'YES or YES',
#                                               'artis': 'TWICE (트와이스)',
#                                               'genre': 'Dance',
#                                               'title': 'SAY YOU LOVE ME',
#                                               'url': 'RepoSong/Twice/YES or '
#                                                      'YES/02. SAY YOU LOVE '
#                                                      'ME.mp3',
#                                               'year': '20181105'},
#                           'SUNSET': {'album': 'YES or YES',
#                                      'artis': 'TWICE (트와이스)',
#                                      'genre': 'Dance',
#                                      'title': 'SUNSET',
#                                      'url': 'RepoSong/Twice/YES or YES/05. '
#                                             'SUNSET.mp3',
#                                      'year': '20181105'},
#                           'YES or YES': {'album': 'YES or YES',
#                                          'artis': 'TWICE (트와이스)',
#                                          'genre': 'Dance',
#                                          'title': 'YES or YES',
#                                          'url': 'RepoSong/Twice/YES or YES/01. '
#                                                 'YES or YES.mp3',
#                                          'year': '20181105'},
#                           'YOUNG & WILD': {'album': 'YES or YES',
#                                            'artis': 'TWICE (트와이스)',
#                                            'genre': 'Dance',
#                                            'title': 'YOUNG & WILD',
#                                            'url': 'RepoSong/Twice/YES or '
#                                                   'YES/04. YOUNG _ WILD.mp3',
#                                            'year': '20181105'}}}}

# %%
import random
import time

def str_time_prop(start, end, format, prop):
    """Get a time at a proportion of a range of two formatted times.

    start and end should be strings specifying times formated in the
    given format (strftime-style), giving an interval [start, end].
    prop specifies how a proportion of the interval to be taken after
    start.  The returned time will be in the specified format.
    """

    stime = time.mktime(time.strptime(start, format))
    etime = time.mktime(time.strptime(end, format))

    ptime = stime + prop * (etime - stime)

    return time.strftime(format, time.localtime(ptime))


def random_date(start, end, prop):
    return str_time_prop(start, end, '%Y-%m-%d', prop)

def generate_date_users():
    return random_date("2015-1-1", "2017-1-1", random.random())
def generate_date_albums():
    return random_date("2017-1-1", "2021-1-1", random.random())
for i in range(0,10):
    newDate = generate_date_albums()
    print(newDate)
# Out:
# 2019-01-20
# 2017-12-13
# 2020-05-22
# 2018-03-18
# 2020-05-20
# 2017-09-27
# 2020-11-05
# 2018-12-22
# 2019-05-18
# 2019-06-03

# %%
c1 = 1
for arts in  artist:
    import hashlib
    newid = hashlib.md5( (arts + str(len(artist[arts]))).encode('utf-8') ).hexdigest()
    print('INSERT INTO user(iduser,username,urlphotoprofile,datejoin,categories) VALUES("' + str(newid) + '","' + str(arts) + '","' + 'RepoSong/' + str(arts) + '/imgprofile.jpg'+ '","' + generate_date_users() + '","1");' )
    print('INSERT INTO artist(iduser) VALUES("' + str(newid) + '");' )
    for album in artist[arts]:
         uniqGenre = {}
         for songs in artist[arts][album]:
             if artist[arts][album][songs]["genre"] in uniqGenre:
                 uniqGenre[artist[arts][album][songs]["genre"]] = uniqGenre[artist[arts][album][songs]["genre"]] + 1
             else :
                 uniqGenre[artist[arts][album][songs]["genre"]] = 1
         print('INSERT INTO album(idalbum,iduser,namealbum,genre,daterelease,urlimagecover) VALUES("' + str(c1) + '","' + str(newid) + '","' + album  + '","' + max(uniqGenre, key=uniqGenre.get) + '","' + generate_date_albums() + '","' + 'RepoSong/' + str(arts)  + '/' + album + '/cover.jpg'  +  '");' )
         #print(max(uniqGenre, key=uniqGenre.get))
         for songs in artist[arts][album]:
             print('INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("' + str(c1) + '","' + str(songs) + '","' + artist[arts][album][songs]["genre"] + '","' + artist[arts][album][songs]["url"]  +  '");' )
         c1 = c1 + 1
# Out:
# INSERT INTO user(iduser,username,urlphotoprofile,datejoin,categories) VALUES("86443871e924f93015bd1b1136606d87","Avicii","RepoSong/Avicii/imgprofile.jpg","2016-11-28","1");
# INSERT INTO artist(iduser) VALUES("86443871e924f93015bd1b1136606d87");
# INSERT INTO album(idalbum,iduser,namealbum,genre,daterelease,urlimagecover) VALUES("1","86443871e924f93015bd1b1136606d87","Stories","Electronic","2018-01-25","RepoSong/Avicii/Stories/cover.jpg");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("1","Waiting For Love","Electronic","RepoSong/Avicii/Stories/01. Waiting For Love.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("1","Talk To Myself","Electronic","RepoSong/Avicii/Stories/02. Talk To Myself.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("1","Touch Me","Electronic","RepoSong/Avicii/Stories/03. Touch Me.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("1","Ten More Days","Electronic","RepoSong/Avicii/Stories/04. Ten More Days.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("1","For A Better Day","Electronic","RepoSong/Avicii/Stories/05. For A Better Day.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("1","Broken Arrows","Electronic","RepoSong/Avicii/Stories/06. Broken Arrows.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("1","True Believer","Electronic","RepoSong/Avicii/Stories/07. True Believer.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("1","City Lights","Electronic","RepoSong/Avicii/Stories/08. City Lights.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("1","Pure Grinding","Electronic","RepoSong/Avicii/Stories/09. Pure Grinding.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("1","Sunset Jesus","Electronic","RepoSong/Avicii/Stories/10. Sunset Jesus.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("1","Can't Catch Me","Electronic","RepoSong/Avicii/Stories/11. Can't Catch Me.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("1","Somewhere In Stockholm","Electronic","RepoSong/Avicii/Stories/12. Somewhere In Stockholm.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("1","Trouble","Electronic","RepoSong/Avicii/Stories/13. Trouble.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("1","Gonna Love Ya","Electronic","RepoSong/Avicii/Stories/14. Gonna Love Ya.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("1","The Days","Electronic","RepoSong/Avicii/Stories/15. The Days.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("1","The Nights","Electronic","RepoSong/Avicii/Stories/16. The Nights.mp3");
# INSERT INTO album(idalbum,iduser,namealbum,genre,daterelease,urlimagecover) VALUES("2","86443871e924f93015bd1b1136606d87","The Days _Nights","Dance","2018-08-25","RepoSong/Avicii/The Days _Nights/cover.jpg");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("2","The Days","Dance","RepoSong/Avicii/The Days _Nights/01 The Days.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("2","The Nights","Dance","RepoSong/Avicii/The Days _Nights/02 The Nights.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("2","The Days (Henrik B Remix)","Dance","RepoSong/Avicii/The Days _Nights/03 The Days (Henrik B Remix).mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("2","The Nights (Felix Jaehn Remix)","Dance","RepoSong/Avicii/The Days _Nights/04 The Nights (Felix Jaehn Remix).mp3");
# INSERT INTO album(idalbum,iduser,namealbum,genre,daterelease,urlimagecover) VALUES("3","86443871e924f93015bd1b1136606d87","TIM","Dance","2017-09-12","RepoSong/Avicii/TIM/cover.jpg");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("3","Peace Of Mind (feat. Vargas & Lagola)","Dance","RepoSong/Avicii/TIM/01 Peace Of Mind (feat. Vargas & Lag.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("3","Heaven","Dance","RepoSong/Avicii/TIM/02 Heaven.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("3","SOS (feat. Aloe Blacc)","Dance","RepoSong/Avicii/TIM/03 SOS (feat. Aloe Blacc).mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("3","Tough Love (feat. Agnes & Vargas & Lagola)","Dance","RepoSong/Avicii/TIM/04 Tough Love (feat. Agnes & Vargas.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("3","Bad Reputation (feat. Joe Janiak)","Dance","RepoSong/Avicii/TIM/05 Bad Reputation (feat. Joe Janiak).mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("3","Ain't A Thing (feat. Bonn)","Dance","RepoSong/Avicii/TIM/06 Ain't A Thing (feat. Bonn).mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("3","Hold The Line (feat. A R I Z O N A)","Dance","RepoSong/Avicii/TIM/07 Hold The Line (feat. A R I Z O N.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("3","Freak (feat. Bonn)","Dance","RepoSong/Avicii/TIM/08 Freak (feat. Bonn).mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("3","Excuse Me Mr Sir (feat. Vargas & Lagola)","Dance","RepoSong/Avicii/TIM/09 Excuse Me Mr Sir (feat. Vargas &.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("3","Heart Upon My Sleeve","Dance","RepoSong/Avicii/TIM/10 Heart Upon My Sleeve.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("3","Never Leave Me (feat. Joe Janiak)","Dance","RepoSong/Avicii/TIM/11 Never Leave Me (feat. Joe Janiak).mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("3","Fades Away (feat. Noonie Bao)","Dance","RepoSong/Avicii/TIM/12 Fades Away (feat. Noonie Bao).mp3");
# INSERT INTO user(iduser,username,urlphotoprofile,datejoin,categories) VALUES("99943c24d30e8fec87cd5cd361260589","Justin Bieber","RepoSong/Justin Bieber/imgprofile.jpg","2016-11-06","1");
# INSERT INTO artist(iduser) VALUES("99943c24d30e8fec87cd5cd361260589");
# INSERT INTO album(idalbum,iduser,namealbum,genre,daterelease,urlimagecover) VALUES("4","99943c24d30e8fec87cd5cd361260589","Justice","Pop","2020-09-17","RepoSong/Justin Bieber/Justice/cover.jpg");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("4","2 Much","Pop","RepoSong/Justin Bieber/Justice/01. 2 Much.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("4","Deserve You","Pop","RepoSong/Justin Bieber/Justice/02. Deserve You.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("4","As I Am","Pop","RepoSong/Justin Bieber/Justice/03. As I Am.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("4","Off My Face","Pop","RepoSong/Justin Bieber/Justice/04. Off My Face.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("4","Holy","Pop","RepoSong/Justin Bieber/Justice/05. Holy.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("4","Unstable","Pop","RepoSong/Justin Bieber/Justice/06. Unstable.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("4","MLK Interlude","Pop","RepoSong/Justin Bieber/Justice/07. MLK Interlude.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("4","Die For You","Pop","RepoSong/Justin Bieber/Justice/08. Die For You.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("4","Hold On","Pop","RepoSong/Justin Bieber/Justice/09. Hold On.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("4","Somebody","Pop","RepoSong/Justin Bieber/Justice/10. Somebody.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("4","Ghost","Pop","RepoSong/Justin Bieber/Justice/11. Ghost.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("4","Peaches","Pop","RepoSong/Justin Bieber/Justice/12. Peaches.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("4","Love You Different","Pop","RepoSong/Justin Bieber/Justice/13. Love You Different.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("4","Loved By You","Pop","RepoSong/Justin Bieber/Justice/14. Loved By You.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("4","Anyone","Pop","RepoSong/Justin Bieber/Justice/15. Anyone.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("4","Lonely","Pop","RepoSong/Justin Bieber/Justice/16. Lonely.mp3");
# INSERT INTO user(iduser,username,urlphotoprofile,datejoin,categories) VALUES("060df8350d95587946d33929848d8cf9","Maroon 5","RepoSong/Maroon 5/imgprofile.jpg","2016-09-05","1");
# INSERT INTO artist(iduser) VALUES("060df8350d95587946d33929848d8cf9");
# INSERT INTO album(idalbum,iduser,namealbum,genre,daterelease,urlimagecover) VALUES("5","060df8350d95587946d33929848d8cf9","Overexposed","Pop","2018-05-31","RepoSong/Maroon 5/Overexposed/cover.jpg");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("5","One More Night","Pop","RepoSong/Maroon 5/Overexposed/01 One More Night.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("5","Payphone (feat. Wiz Khalifa)","Pop","RepoSong/Maroon 5/Overexposed/02 Payphone (feat. Wiz Khalifa).mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("5","Daylight","Pop","RepoSong/Maroon 5/Overexposed/03 Daylight.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("5","Lucky Strike","Pop","RepoSong/Maroon 5/Overexposed/04 Lucky Strike.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("5","The Man Who Never Lied","Pop","RepoSong/Maroon 5/Overexposed/05 The Man Who Never Lied.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("5","Love Somebody","Pop","RepoSong/Maroon 5/Overexposed/06 Love Somebody.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("5","Ladykiller","Pop","RepoSong/Maroon 5/Overexposed/07 Ladykiller.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("5","Fortune Teller","Pop","RepoSong/Maroon 5/Overexposed/08 Fortune Teller.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("5","Sad","Pop","RepoSong/Maroon 5/Overexposed/09 Sad.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("5","Tickets","Pop","RepoSong/Maroon 5/Overexposed/10 Tickets.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("5","Doin' Dirt","Pop","RepoSong/Maroon 5/Overexposed/11 Doin' Dirt.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("5","Beautiful Goodbye","Pop","RepoSong/Maroon 5/Overexposed/12 Beautiful Goodbye.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("5","Wipe Your Eyes","Pop","RepoSong/Maroon 5/Overexposed/13 Wipe Your Eyes.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("5","Wasted Years","Pop","RepoSong/Maroon 5/Overexposed/14 Wasted Years.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("5","Kiss","Pop","RepoSong/Maroon 5/Overexposed/15 Kiss.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("5","Moves Like Jagger (feat. Christina Aguilera) [Studio Recording from The Voice Performance]","Pop","RepoSong/Maroon 5/Overexposed/16 Moves Like Jagger (feat. Christin.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("5","One More Night (Sticky K Remix)","Pop","RepoSong/Maroon 5/Overexposed/17 One More Night (Sticky K Remix).mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("5","Payphone (feat. Wiz Khalifa) [Cutmore Remix]","Pop","RepoSong/Maroon 5/Overexposed/18 Payphone (feat. Wiz Khalifa) [Cut.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("5","Payphone (feat. Wiz Khalifa) [Supreme Cuts Remix]","Pop","RepoSong/Maroon 5/Overexposed/19 Payphone (feat. Wiz Khalifa) [Sup.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("5","Payphone (feat. Wiz Khalifa) [Sound of Arrows Remix]","Pop","RepoSong/Maroon 5/Overexposed/20 Payphone (feat. Wiz Khalifa) [Sou.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("5","Payphone (feat. Wiz Khalifa) [The Others Remix]","Pop","RepoSong/Maroon 5/Overexposed/21 Payphone (feat. Wiz Khalifa) [The.mp3");
# INSERT INTO album(idalbum,iduser,namealbum,genre,daterelease,urlimagecover) VALUES("6","060df8350d95587946d33929848d8cf9","Red Pill Blues","Pop Rock","2019-08-29","RepoSong/Maroon 5/Red Pill Blues/cover.jpg");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("6","Best 4 U","Pop Rock","RepoSong/Maroon 5/Red Pill Blues/1.01 - Maroon 5 - Best 4 U.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("6","What Loves Do (Feat. Sza)","Pop Rock","RepoSong/Maroon 5/Red Pill Blues/1.02 - Maroon 5 - What Lovers Do (feat. SZA).mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("6","Wait","Pop Rock","RepoSong/Maroon 5/Red Pill Blues/1.03 - Maroon 5 - Wait.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("6","Lips On You","Pop Rock","RepoSong/Maroon 5/Red Pill Blues/1.04 - Maroon 5 - Lips On You.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("6","Bet My Heart","Pop Rock","RepoSong/Maroon 5/Red Pill Blues/1.05 - Maroon 5 - Bet My Heart.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("6","Help Me Out (Feat. Julia Michaels)","Pop Rock","RepoSong/Maroon 5/Red Pill Blues/1.06 - Maroon 5 & Julia Michaels - Help Me Out.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("6","Who I Am (Feat. Lunchmoney Lewis)","Pop Rock","RepoSong/Maroon 5/Red Pill Blues/1.07 - Maroon 5 - Who I Am (feat. Lunchmoney Lewis).mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("6","Whiskey (Feat. A$ap Rocky)","Pop Rock","RepoSong/Maroon 5/Red Pill Blues/1.08 - Maroon 5 - Whiskey (feat. A$AP Rocky).mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("6","Girls Like You","Pop Rock","RepoSong/Maroon 5/Red Pill Blues/1.09 - Maroon 5 - Girls Like You.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("6","Closure","Pop Rock","RepoSong/Maroon 5/Red Pill Blues/1.10 - Maroon 5 - Closure.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("6","Denim Jacket","Pop Rock","RepoSong/Maroon 5/Red Pill Blues/1.11 - Maroon 5 - Denim Jacket.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("6","Visions","Pop Rock","RepoSong/Maroon 5/Red Pill Blues/1.12 - Maroon 5 - Visions.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("6","Don't Wanna Know (Feat. Kendrick Lamar)","Pop Rock","RepoSong/Maroon 5/Red Pill Blues/1.13 - Maroon 5 - Don't Wanna Know (feat. Kendrick Lamar).mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("6","Cold (Feat. Future)","Pop Rock","RepoSong/Maroon 5/Red Pill Blues/1.14- Maroon 5 - Cold (feat. Future).mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("6","Moves Like Jagger (Live In Manchester)","Pop Rock","RepoSong/Maroon 5/Red Pill Blues/1.15 - Maroon 5 - Moves Like Jagger (Live In Manchester).mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("6","Stereo Hearts (Live In Manchester)","Pop Rock","RepoSong/Maroon 5/Red Pill Blues/1.16 - Maroon 5 - Stereo Hearts (Live In Manchester).mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("6","Animals (Live In Manchester)","Pop Rock","RepoSong/Maroon 5/Red Pill Blues/1.17 - Maroon 5 - Animals (Live In Manchester).mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("6","Daylight (Live In Manchester)","Pop Rock","RepoSong/Maroon 5/Red Pill Blues/1.18 - Maroon 5 - Daylight (Live In Manchester).mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("6","Maps (Live In Manchester)","Pop Rock","RepoSong/Maroon 5/Red Pill Blues/1.19 - Maroon 5 - Maps (Live In Manchester).mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("6","This Love (Live In Manchester)","Pop Rock","RepoSong/Maroon 5/Red Pill Blues/1.20 - Maroon 5 - This Love (Live In Manchester).mp3");
# INSERT INTO album(idalbum,iduser,namealbum,genre,daterelease,urlimagecover) VALUES("7","060df8350d95587946d33929848d8cf9","The Best Songs","Other","2019-09-05","RepoSong/Maroon 5/The Best Songs/cover.jpg");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("7","She Will Be Loved","Other","RepoSong/Maroon 5/The Best Songs/01. She Will Be Loved.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("7","Payphone","Other","RepoSong/Maroon 5/The Best Songs/02. Payphone.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("7","Moves Like Jagger (feat. Christina Aguilera)","Other","RepoSong/Maroon 5/The Best Songs/03.  Moves Like Jagger.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("7","This Love","Other","RepoSong/Maroon 5/The Best Songs/04. This Love.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("7","Misery","Other","RepoSong/Maroon 5/The Best Songs/05. Misery.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("7","One More Night","Other","RepoSong/Maroon 5/The Best Songs/06. One More Night.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("7","Won't Go Home Without You","Other","RepoSong/Maroon 5/The Best Songs/07. Won't Go Home Without You.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("7","Sunday Morning","Other","RepoSong/Maroon 5/The Best Songs/08. Sunday Morning.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("7","Never Gonna Leave This Bed","Other","RepoSong/Maroon 5/The Best Songs/09. Never Gonna Leave This Bed.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("7","Wake Up Call","Other","RepoSong/Maroon 5/The Best Songs/10. Wake Up Call.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("7","Give a Little More","Other","RepoSong/Maroon 5/The Best Songs/11. Give A Little More.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("7","Stutter","Other","RepoSong/Maroon 5/The Best Songs/12. Stutter.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("7","Get Back in My Life","Other","RepoSong/Maroon 5/The Best Songs/13. Get Back In My Life.mp3");
# INSERT INTO user(iduser,username,urlphotoprofile,datejoin,categories) VALUES("49bb0bdcf7f96c6d96366e5d20bd660d","Martin Garrix","RepoSong/Martin Garrix/imgprofile.jpg","2015-03-09","1");
# INSERT INTO artist(iduser) VALUES("49bb0bdcf7f96c6d96366e5d20bd660d");
# INSERT INTO album(idalbum,iduser,namealbum,genre,daterelease,urlimagecover) VALUES("8","49bb0bdcf7f96c6d96366e5d20bd660d","Bylaw EP","Dance","2020-10-31","RepoSong/Martin Garrix/Bylaw EP/cover.jpg");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("8","Breach (Walk Alone)","Dance","RepoSong/Martin Garrix/Bylaw EP/01. Breach (Walk Alone).mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("8","Yottabyte","Dance","RepoSong/Martin Garrix/Bylaw EP/02. Yottabyte.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("8","Latency","Dance","RepoSong/Martin Garrix/Bylaw EP/03. Latency.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("8","Access","Dance","RepoSong/Martin Garrix/Bylaw EP/04. Access.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("8","Waiting for Tomorrow (feat. Mike Shinoda)","Dance","RepoSong/Martin Garrix/Bylaw EP/05. Waiting for Tomorrow (feat. Mike Shinoda).mp3");
# INSERT INTO album(idalbum,iduser,namealbum,genre,daterelease,urlimagecover) VALUES("9","49bb0bdcf7f96c6d96366e5d20bd660d","Seven","Dance","2020-12-26","RepoSong/Martin Garrix/Seven/cover.jpg");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("9","Wiee","Dance","RepoSong/Martin Garrix/Seven/01. Wiee.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("9","Sun Is Never Going Down (feat. Dawn Golden)","Dance","RepoSong/Martin Garrix/Seven/02. Sun Is Never Going Down (Ft. Dawn Golden).mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("9","Spotless","Dance","RepoSong/Martin Garrix/Seven/03. Spotless (Ft. Jay Hardway).mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("9","Hold On & Believe (feat. The Federal Empire)","Dance","RepoSong/Martin Garrix/Seven/04. Hold On & Believe (Ft. The Federal Empire).mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("9","Welcome","Dance","RepoSong/Martin Garrix/Seven/05. Welcome (Ft. Julian Jordan).mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("9","Together","Dance","RepoSong/Martin Garrix/Seven/06. Together (Ft. Matisse & Sadko).mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("9","Make Up Your Mind","Dance","RepoSong/Martin Garrix/Seven/07. Make Up Your Mind (Ft.  Florian Picasso).mp3");
# INSERT INTO user(iduser,username,urlphotoprofile,datejoin,categories) VALUES("bd2a26bc91993371b551a1ab7fc7d6fa","Taylor Swift","RepoSong/Taylor Swift/imgprofile.jpg","2015-07-18","1");
# INSERT INTO artist(iduser) VALUES("bd2a26bc91993371b551a1ab7fc7d6fa");
# INSERT INTO album(idalbum,iduser,namealbum,genre,daterelease,urlimagecover) VALUES("10","bd2a26bc91993371b551a1ab7fc7d6fa","Lover","Pop","2019-06-02","RepoSong/Taylor Swift/Lover/cover.jpg");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("10","I Forgot That You Existed","Pop","RepoSong/Taylor Swift/Lover/01 I Forgot That You Existed.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("10","Cruel Summer","Pop","RepoSong/Taylor Swift/Lover/02 Cruel Summer.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("10","Lover","Pop","RepoSong/Taylor Swift/Lover/03 Lover.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("10","The Man","Pop","RepoSong/Taylor Swift/Lover/04 The Man.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("10","The Archer","Pop","RepoSong/Taylor Swift/Lover/05 The Archer.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("10","I Think He Knows","Pop","RepoSong/Taylor Swift/Lover/06 I Think He Knows.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("10","Miss Americana & The Heartbreak Prince","Pop","RepoSong/Taylor Swift/Lover/07 Miss Americana & The Heartbreak P.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("10","Paper Rings","Pop","RepoSong/Taylor Swift/Lover/08 Paper Rings.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("10","Cornelia Street","Pop","RepoSong/Taylor Swift/Lover/09 Cornelia Street.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("10","Death By A Thousand Cuts","Pop","RepoSong/Taylor Swift/Lover/10 Death By A Thousand Cuts.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("10","London Boy","Pop","RepoSong/Taylor Swift/Lover/11 London Boy.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("10","Soon You'll Get Better (feat. Dixie Chicks)","Pop","RepoSong/Taylor Swift/Lover/12 Soon You'll Get Better (feat. Dix.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("10","False God","Pop","RepoSong/Taylor Swift/Lover/13 False God.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("10","You Need To Calm Down","Pop","RepoSong/Taylor Swift/Lover/14 You Need To Calm Down.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("10","Afterglow","Pop","RepoSong/Taylor Swift/Lover/15 Afterglow.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("10","ME! (feat. Brendon Urie of Panic! At the Disco)","Pop","RepoSong/Taylor Swift/Lover/16 ME! (feat. Brendon Urie of Panic!.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("10","It's Nice To Have A Friend","Pop","RepoSong/Taylor Swift/Lover/17 It's Nice To Have A Friend.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("10","Daylight","Pop","RepoSong/Taylor Swift/Lover/18 Daylight.mp3");
# INSERT INTO user(iduser,username,urlphotoprofile,datejoin,categories) VALUES("ac5efcda3b54ab857671c1513f57ed09","Twice","RepoSong/Twice/imgprofile.jpg","2015-04-10","1");
# INSERT INTO artist(iduser) VALUES("ac5efcda3b54ab857671c1513f57ed09");
# INSERT INTO album(idalbum,iduser,namealbum,genre,daterelease,urlimagecover) VALUES("11","ac5efcda3b54ab857671c1513f57ed09","&TWICE","K-Pop","2018-11-16","RepoSong/Twice/&TWICE/cover.jpg");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("11","Fake & True","K-Pop","RepoSong/Twice/&TWICE/01 Fake & True.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("11","Stronger","K-Pop","RepoSong/Twice/&TWICE/02 Stronger.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("11","Breakthrough","K-Pop","RepoSong/Twice/&TWICE/03 Breakthrough.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("11","Changing!","K-Pop","RepoSong/Twice/&TWICE/04 Changing!.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("11","HAPPY HAPPY","K-Pop","RepoSong/Twice/&TWICE/05 HAPPY HAPPY.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("11","What You Waiting For","K-Pop","RepoSong/Twice/&TWICE/06 What You Waiting For.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("11","Be OK","K-Pop","RepoSong/Twice/&TWICE/07 Be OK.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("11","POLISH","K-Pop","RepoSong/Twice/&TWICE/08 POLISH.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("11","How u doin'","K-Pop","RepoSong/Twice/&TWICE/09 How u doin'.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("11","The Reason Why","K-Pop","RepoSong/Twice/&TWICE/10 The Reason Why.mp3");
# INSERT INTO album(idalbum,iduser,namealbum,genre,daterelease,urlimagecover) VALUES("12","ac5efcda3b54ab857671c1513f57ed09","FEEL SPECIAL","Dance","2018-12-15","RepoSong/Twice/FEEL SPECIAL/cover.jpg");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("12","Feel Special","Dance","RepoSong/Twice/FEEL SPECIAL/01. Feel Special.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("12","RAINBOW","Dance","RepoSong/Twice/FEEL SPECIAL/02. RAINBOW.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("12","GET LOUD","Dance","RepoSong/Twice/FEEL SPECIAL/03. GET LOUD.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("12","TRICK IT","Dance","RepoSong/Twice/FEEL SPECIAL/04. TRICK IT.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("12","LOVE FOOLISH","Electronica","RepoSong/Twice/FEEL SPECIAL/05. LOVE FOOLISH.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("12","21:29","Ballad","RepoSong/Twice/FEEL SPECIAL/06. 21_29.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("12","BREAKTHROUGH (Korean Ver.)","Dance","RepoSong/Twice/FEEL SPECIAL/07. BREAKTHROUGH (Korean Ver.).mp3");
# INSERT INTO album(idalbum,iduser,namealbum,genre,daterelease,urlimagecover) VALUES("13","ac5efcda3b54ab857671c1513f57ed09","YES or YES","Dance","2020-10-28","RepoSong/Twice/YES or YES/cover.jpg");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("13","YES or YES","Dance","RepoSong/Twice/YES or YES/01. YES or YES.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("13","SAY YOU LOVE ME","Dance","RepoSong/Twice/YES or YES/02. SAY YOU LOVE ME.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("13","LALALA","Dance","RepoSong/Twice/YES or YES/03. LALALA.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("13","YOUNG & WILD","Dance","RepoSong/Twice/YES or YES/04. YOUNG _ WILD.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("13","SUNSET","Dance","RepoSong/Twice/YES or YES/05. SUNSET.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("13","AFTER MOON","Ballad","RepoSong/Twice/YES or YES/06. AFTER MOON.mp3");
# INSERT INTO song(idalbum,title,genre,urlsongs) VALUES("13","BDZ (Korean Ver.)","Dance","RepoSong/Twice/YES or YES/07. BDZ (Korean Ver.).mp3");
